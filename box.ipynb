# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('ggplot')
# %matplotlib inline

# %%
df1 = pd.read_csv('dbpedia/1millon-False-False.csv')
df1.plot.box(title="Zoi's algorithm with 1e6 triples"); 
df1.plot(title="Zoi's algorithm with 1e6 triples");

# %%
df2 = pd.read_csv('dbpedia/1millon-False-True.csv')
df2.plot.box(title="Mixed algorithm with 1e6 triples"); 
df2.plot(title="Mixed algorithm with 1e6 triples");

# %%
df3 = pd.read_csv('dbpedia/1millon-True-False.csv')
plt.figure(); 
df3.plot.box(title="Proposed algorithm with 1e6 triples (B=5000) "); 
df3.plot(title="Proposed algorithm with 1e6 triples (B=5000) ");

# %%
df4 = pd.read_csv('dbpedia/1millon-10000-False.csv')
df4.plot.box(title="Proposed algorithm with 1e6 triples (B=10000) "); 
df4.plot(title="Proposed algorithm with 1e6 triples (B=10000) ");
