# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('ggplot')
# %matplotlib inline

# %%
print ("Simulation using ATLAS Zoi Kaoudi")
df1 = pd.read_csv('dbpedia/1millon-False-False.csv')
df2 = pd.read_csv('dbpedia/1millon-False-True.csv')
df3 = pd.read_csv('dbpedia/1millon-True-False.csv')
df4 = pd.read_csv('dbpedia/1millon-10000-False.csv')
df5 = pd.read_csv('dbpedia/1millon-None-False.csv')

df1['triples'][140]=0

#delete outlier
for i in [df1,df2,df3,df4,df5]:
    print (i.describe())
    plt.figure(); i.plot.box();
    plt.figure(); i.plot();
# Out:
# Simulation using ATLAS Zoi Kaoudi
#             triples
# count   1001.000000
# mean    1997.065934
# std     2012.607365
# min        0.000000
# 25%      600.000000
# 50%     1306.000000
# 75%     2769.000000
# max    18684.000000
#             triples
# count   1001.000000
# mean    2990.099900
# std     3086.760023
# min        0.000000
# 25%      748.000000
# 50%     2081.000000
# 75%     4070.000000
# max    24093.000000
#            triples
# count  1001.000000
# mean   1562.725275
# std    1270.636461
# min       0.000000
# 25%     534.000000
# 50%    1239.000000
# 75%    2375.000000
# max    4952.000000
#            triples
# count  1001.000000
# mean   1926.527473
# std    1873.308484
# min       0.000000
# 25%     528.000000
# 50%    1355.000000
# 75%    2721.000000
# max    9963.000000
#             triples
# count  1.001000e+03
# mean   2.992826e+03
# std    3.165255e+04
# min    0.000000e+00
# 25%    5.320000e+02
# 50%    1.347000e+03
# 75%    2.790000e+03
# ...
